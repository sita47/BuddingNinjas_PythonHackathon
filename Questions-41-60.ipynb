# %%
####################################### 41 ###############################################

# %%
##### 41. Find the visit type with maximum 'No Show' #####

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
# Reading  HospitalDatabase file's sheet 'AmbulatoryVisits'  

df41AV = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'AmbulatoryVisits' )

# %%
# To check no. of unique values in column VisitType
df41AV["VisitType"].unique()
# Out:
# array(['Physical', 'Follow Up', 'Telemedicine', 'New'], dtype=object)

# %%
# To extract  column name 'VisitStatus' into a seperate dataframe
df41vs = df41AV.groupby("VisitStatus")

# %%
# To extract values from dataframe 'VisitStatus' based on condition with 'NoShow'
df41NS = df41vs.get_group("No Show")
df41NS
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 0        202         840          29  2019-03-19 2019-03-13 07:59:24.000
# 1        436         820          25  2019-03-19 2019-02-24 07:10:31.043
# 2        794         879          30  2019-04-02 2019-03-19 01:41:55.656
# 3        799         884          37  2019-03-03 2019-02-25 01:25:39.696
# 4        515          32          26  2019-03-16 2019-02-20 06:44:59.617
# ..       ...         ...         ...         ...                     ...
# 149      414          90           3  2019-02-25 2019-02-17 14:34:07.328
# 150      507         891          16  2019-01-25 2019-01-14 03:04:39.696
# 151      410          90          22  2019-02-21 2019-01-31 11:29:47.000
# 152      803         888          15  2019-03-07 2019-02-25 11:54:27.274
# 153      505         889          14  2019-01-23 2019-01-22 18:33:07.452
#
#      VisitDepartmentID     VisitType  BloodPressureSystolic  \
# 0                   10      Physical                  188.0
# 1                    3     Follow Up                  179.0
# 2                   11  Telemedicine                  133.0
# 3                    4  Telemedicine                  132.0
# 4                   11  Telemedicine                  131.0
# ..                 ...           ...                    ...
# 149                  5     Follow Up                  136.0
# 150                 11  Telemedicine                  155.0
# 151                  1     Follow Up                  131.0
# 152                  8  Telemedicine                  173.0
# 153                  9  Telemedicine                  136.0
#
#      BloodPressureDiastolic      Pulse VisitStatus
# 0                144.143427  83.044920     No Show
# 1                118.876808  90.309544     No Show
# 2                 98.749563  80.859776     No Show
# 3                 98.001270  82.184737     No Show
# 4                 85.115632  89.192362     No Show
# ..                      ...        ...         ...
# 149               90.802316  79.426026     No Show
# 150              112.064259  73.714965     No Show
# 151               80.726116  54.947675     No Show
# 152              136.377032  58.024363     No Show
# 153               99.161951  66.998029     No Show
#
# [154 rows x 11 columns]

# %%
# To extract max count of the VisitType field from dataframe 'NoShow' 
df41=df41NS["VisitType"].unique().max()
df41
# Out:
# 'Telemedicine'

# %%
#  ## ADITIONAL ANALYSIS : Verification : We can see Telemedicine is the highest

df41_verify = df41NS['VisitType'].value_counts()
df41_verify
# Out:
# Telemedicine    74
# Follow Up       41
# Physical        39
# Name: VisitType, dtype: int64

# %%
####################################### 42 ####################################################

# %%
### 42. Using loc , get the details of the providers where providerId is between 11 and 20 and ProviderSpecialty is Surgery ####

# %%
df42P = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'Providers' )

# %%
df42P.head()
# Out:
#    ProviderID    ProviderName ProviderSpecialty     ProviderDateOnStaff
# 0           1       Sally Sue        Pediatrics 1993-01-01 00:00:00.000
# 1           2      Mike Myers        Pediatrics 1993-05-02 00:00:17.695
# 2           3  Jordan Michael        Pediatrics 1993-06-24 21:31:46.687
# 3           4       Ted Texas        Pediatrics 1993-12-23 21:33:52.299
# 4           5        Ala Bama        Pediatrics 1995-01-10 02:53:47.838

# %%
df42P[(df42P["ProviderID"] >=11) & (df42P["ProviderID"] <=20)]
# Out:
#     ProviderID     ProviderName ProviderSpecialty     ProviderDateOnStaff
# 10          11     Kim Kimberly           Surgery 1998-05-10 14:47:29.468
# 11          12         Sarah Ab           Surgery 1998-08-18 05:22:40.762
# 12          13  Abigail Marriot           Surgery 1998-11-08 12:25:45.705
# 13          14          Dave Yu           Surgery 1999-06-26 16:18:57.436
# 14          15  Christian Saint           Surgery 2000-08-27 00:12:40.326
# 15          16     Perry Pardon           Surgery 2001-02-13 11:49:17.862
# 16          17     Kent Kendall        Cardiology 2001-12-22 11:18:32.919
# 17          18       Ryan Kevin        Cardiology 2003-01-14 21:16:34.778
# 18          19     Tyler Conner        Cardiology 2003-07-09 02:41:40.410
# 19          20    Bailey Barret        Cardiology 2003-08-20 16:05:50.179

# %%
df42 = df42P.loc[(df42P.ProviderID >= 11) & (df42P.ProviderID <= 20) & (df42P.ProviderSpecialty =='Surgery')]
df42
# Out:
#     ProviderID     ProviderName ProviderSpecialty     ProviderDateOnStaff
# 10          11     Kim Kimberly           Surgery 1998-05-10 14:47:29.468
# 11          12         Sarah Ab           Surgery 1998-08-18 05:22:40.762
# 12          13  Abigail Marriot           Surgery 1998-11-08 12:25:45.705
# 13          14          Dave Yu           Surgery 1999-06-26 16:18:57.436
# 14          15  Christian Saint           Surgery 2000-08-27 00:12:40.326
# 15          16     Perry Pardon           Surgery 2001-02-13 11:49:17.862

# %%
####################################### 43 ###################################################

# %%
### 43. Write a regular expression to find all the digits and numbers in the string ###

# %%
import re

# %%
str = "NUM22/7-9JA-2022-DAML-25-26"
df43 = re.findall(r'[0-9]+', str)
print(df43)
# Out:
# ['22', '7', '9', '2022', '25', '26']

# %%
####################################### 44 ###############################################

# %%
# 44. Create a pivot table displaying average LOS based on Service and Primary Diagnosis

# %%
import datetime

# %%
# Reading  HospitalDatabase file's sheet 'Discharges' 
df44DT = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'Discharges')
df44DT
# Out:
#      AdmissionID  PatientID AdmissionDate           DischargeDate  \
# 0              1          9    2018-01-01 2018-01-07 18:06:06.408
# 1            257         93    2018-01-06 2018-01-18 02:59:04.667
# 2            152        101    2018-01-07 2018-01-11 16:16:06.782
# 3            361        102    2018-01-07 2018-01-15 04:48:33.134
# 4            258        103    2018-01-07 2018-01-15 13:32:36.157
# ..           ...        ...           ...                     ...
# 715          715        716    2018-02-21 2018-03-06 03:31:05.262
# 716          698        723    2018-02-22 2018-02-26 15:09:02.584
# 717          704        724    2018-02-22 2018-02-27 07:59:32.385
# 718          716        733    2018-02-22 2018-03-05 12:31:55.958
# 719          710        742    2018-02-22 2018-03-10 20:38:30.568
#
#     DischargeDisposition           Service PrimaryDiagnosis  ExpectedLOS  \
# 0                Expired        Cardiology              AMI     9.646857
# 1                Expired        Cardiology       Broken Leg     6.816558
# 2                Expired        Cardiology   Kidney Failure     6.580273
# 3                Expired        Cardiology             Afib    12.794536
# 4                Expired        Cardiology       Broken Leg     2.639297
# ..                   ...               ...              ...          ...
# 715             Transfer               ICU    Heart Failure    11.362095
# 716             Transfer               ICU    Heart Failure    10.262312
# 717             Transfer  General Medicine        Pneumonia     6.036234
# 718             Transfer               ICU    Heart Failure    13.323413
# 719             Transfer  General Medicine         Diabetes     7.195441
#
#      ExpectedMortality
# 0             0.061540
# 1             0.628827
# 2             0.573887
# 3             0.222163
# 4             0.055468
# ..                 ...
# 715           0.370695
# 716           0.812930
# 717           0.094128
# 718           0.490892
# 719           0.286439
#
# [720 rows x 9 columns]

# %%
df44DT['AdmissionDate'] = pd.to_datetime(df44DT['AdmissionDate'])
df44DT['DischargeDate'] = pd.to_datetime(df44DT['DischargeDate'])

# %%
df44DTa= df44DT
df44DTa['AdmissionDate'] = pd.to_datetime(df44DT['AdmissionDate']).dt.date
df44DTa['DischargeDate'] = pd.to_datetime(df44DT['DischargeDate']).dt.date
df44DTa
# Out:
#      AdmissionID  PatientID AdmissionDate DischargeDate DischargeDisposition  \
# 0              1          9    2018-01-01    2018-01-07              Expired
# 1            257         93    2018-01-06    2018-01-18              Expired
# 2            152        101    2018-01-07    2018-01-11              Expired
# 3            361        102    2018-01-07    2018-01-15              Expired
# 4            258        103    2018-01-07    2018-01-15              Expired
# ..           ...        ...           ...           ...                  ...
# 715          715        716    2018-02-21    2018-03-06             Transfer
# 716          698        723    2018-02-22    2018-02-26             Transfer
# 717          704        724    2018-02-22    2018-02-27             Transfer
# 718          716        733    2018-02-22    2018-03-05             Transfer
# 719          710        742    2018-02-22    2018-03-10             Transfer
#
#               Service PrimaryDiagnosis  ExpectedLOS  ExpectedMortality
# 0          Cardiology              AMI     9.646857           0.061540
# 1          Cardiology       Broken Leg     6.816558           0.628827
# 2          Cardiology   Kidney Failure     6.580273           0.573887
# 3          Cardiology             Afib    12.794536           0.222163
# 4          Cardiology       Broken Leg     2.639297           0.055468
# ..                ...              ...          ...                ...
# 715               ICU    Heart Failure    11.362095           0.370695
# 716               ICU    Heart Failure    10.262312           0.812930
# 717  General Medicine        Pneumonia     6.036234           0.094128
# 718               ICU    Heart Failure    13.323413           0.490892
# 719  General Medicine         Diabetes     7.195441           0.286439
#
# [720 rows x 9 columns]

# %%
df44DTa['LengthOS1'] = (df44DTa['DischargeDate']) - (df44DTa['AdmissionDate'])
LOS44 = df44DTa

# %%
df44DTa['LengthOS1']
# Out:
# 0      6 days
# 1     12 days
# 2      4 days
# 3      8 days
# 4      8 days
#         ...
# 715   13 days
# 716    4 days
# 717    5 days
# 718   11 days
# 719   16 days
# Name: LengthOS1, Length: 720, dtype: timedelta64[ns]

# %%
pivot44 = df44DTa.pivot_table(index = ['Service', 'PrimaryDiagnosis'], 
                       values = ['LengthOS1' ], aggfunc ='mean')

pivot44
# Out:
#                                                      LengthOS1
# Service          PrimaryDiagnosis
# Cardiology       AMI                          10 days 06:00:00
#                  Afib                         11 days 04:48:00
#                  Broken Leg                   10 days 16:00:00
#                  Flu                          12 days 00:00:00
#                  Heart Failure       9 days 12:18:27.692307692
#                  Kidney Failure                4 days 00:00:00
# General Medicine Broken Leg                   13 days 00:00:00
#                  Diabetes           10 days 06:56:50.526315789
#                  Fever                         8 days 00:00:00
#                  Flu                           9 days 21:20:00
#                  Hypertension        8 days 21:56:34.285714285
#                  Kidney Failure               10 days 16:00:00
#                  Laceration          9 days 10:17:08.571428571
#                  Pneumonia           9 days 10:01:47.462686567
#                  Stroke                       11 days 06:00:00
# Hospitalist      AMI                          10 days 00:00:00
#                  Broken Leg                    7 days 16:00:00
#                  Diabetes            8 days 20:18:27.692307692
#                  Fever                        10 days 16:00:00
#                  Flu                 8 days 17:41:03.157894736
#                  Hypertension                 10 days 16:00:00
#                  Kidney Failure               10 days 04:00:00
#                  Knee Replacement              6 days 00:00:00
#                  Laceration                    9 days 00:00:00
#                  Pneumonia           8 days 22:17:08.571428571
#                  Stroke                       16 days 00:00:00
# ICU              AMI                          12 days 04:48:00
#                  Afib                          6 days 00:00:00
#                  Fever                        13 days 08:00:00
#                  Flu                           8 days 00:00:00
#                  Heart Failure       9 days 10:54:32.727272727
#                  Hypertension                  8 days 12:00:00
#                  Kidney Failure               11 days 00:00:00
#                  Laceration                   15 days 00:00:00
#                  Pneumonia           8 days 07:10:07.792207792
#                  Spinal Cord Injury           10 days 00:00:00
#                  Stroke                       10 days 08:00:00
# Neurology        AMI                           9 days 00:00:00
#                  Flu                           7 days 00:00:00
#                  Heart Failure                13 days 04:00:00
#                  Hypertension                  9 days 00:00:00
#                  Migraine                      8 days 14:00:00
#                  Pain               10 days 06:51:25.714285714
#                  Pneumonia                     9 days 19:12:00
#                  Stroke              9 days 14:46:09.230769230
# Orthopeadics     Hip Fracture        9 days 04:10:26.086956521
#                  Knee Replacement              9 days 12:00:00

# %%
####################################### 45 ###############################################

# %%
# 45. Calculate mortality by diagnosis

# %%
df45RR = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'ReAdmissionRegistry')

# %%
pivot45 = df45RR.pivot_table(index = ['PrimaryDiagnosis'], 
                       values = ['ExpectedMortality' ], aggfunc ='mean')

pivot45
# Out:
#                     ExpectedMortality
# PrimaryDiagnosis
# AMI                          0.235146
# Afib                         0.304235
# Broken Leg                   0.275440
# Diabetes                     0.286476
# Fever                        0.296601
# Flu                          0.272976
# Heart Failure                0.385678
# Hip Fracture                 0.373310
# Hypertension                 0.296555
# Kidney Failure               0.247592
# Knee Replacement             0.290385
# Laceration                   0.273022
# Migraine                     0.567372
# Pain                         0.548264
# Pneumonia                    0.374618
# Spinal Cord Injury           0.200279
# Stroke                       0.442433

# %%
####################################### 46 ###############################################

# %%
# 46. Write a code to split a sentence into words using regex

# %%
Hack46 = "We are the team Budding Ninjas!"

# %%
list46 = re.findall(r'[A-Za-z]+|[^A-Za-z ]', Hack46)

# %%
list46
# Out:
# ['We', 'are', 'the', 'team', 'Budding', 'Ninjas', '!']

# %%
####################################### 47 ###############################################

# %%
# 47 Using indexing ,loc ,retrieve the row with maximum BloodPressureSystolic

# %%
df47AV = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'AmbulatoryVisits' )

# %%
## Using loc

df47 = df47AV.loc[df47AV["BloodPressureSystolic"] == df47AV["BloodPressureSystolic"].max() ]
df47
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 236      933         884          27  2019-02-14 2019-01-22 19:26:49.163
# 251      888         906          24  2019-03-31 2019-03-17 23:21:17.361
# 424      314          63           7  2019-04-05 2019-03-24 22:31:26.092
# 432      740         892          31  2019-03-14 2019-03-11 15:08:33.963
# 677      929         880          23  2019-02-10 2019-01-22 13:32:14.549
# 869      839         857          12  2019-03-17 2019-02-23 09:05:43.676
# 934      482         866          14  2019-05-04 2019-04-13 07:54:49.580
#
#      VisitDepartmentID     VisitType  BloodPressureSystolic  \
# 236                 12  Telemedicine                  190.0
# 251                 10           New                  190.0
# 424                 11  Telemedicine                  190.0
# 432                  8      Physical                  190.0
# 677                  8     Follow Up                  190.0
# 869                  8     Follow Up                  190.0
# 934                  5           New                  190.0
#
#      BloodPressureDiastolic      Pulse VisitStatus
# 236              143.989174  74.976879   Completed
# 251              137.207999  52.666922   Completed
# 424              121.539859  95.471260   Completed
# 432              145.343479  94.849021   Completed
# 677              144.313400  82.781940   Completed
# 869              130.997386  71.829542   Completed
# 934              124.736359  69.731779    Canceled

# %%
## ADITIONAL ANALYSIS : using indexing
df47i = df47AV[df47AV["BloodPressureSystolic"] == df47AV["BloodPressureSystolic"].max() ]
df47i
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 236      933         884          27  2019-02-14 2019-01-22 19:26:49.163
# 251      888         906          24  2019-03-31 2019-03-17 23:21:17.361
# 424      314          63           7  2019-04-05 2019-03-24 22:31:26.092
# 432      740         892          31  2019-03-14 2019-03-11 15:08:33.963
# 677      929         880          23  2019-02-10 2019-01-22 13:32:14.549
# 869      839         857          12  2019-03-17 2019-02-23 09:05:43.676
# 934      482         866          14  2019-05-04 2019-04-13 07:54:49.580
#
#      VisitDepartmentID     VisitType  BloodPressureSystolic  \
# 236                 12  Telemedicine                  190.0
# 251                 10           New                  190.0
# 424                 11  Telemedicine                  190.0
# 432                  8      Physical                  190.0
# 677                  8     Follow Up                  190.0
# 869                  8     Follow Up                  190.0
# 934                  5           New                  190.0
#
#      BloodPressureDiastolic      Pulse VisitStatus
# 236              143.989174  74.976879   Completed
# 251              137.207999  52.666922   Completed
# 424              121.539859  95.471260   Completed
# 432              145.343479  94.849021   Completed
# 677              144.313400  82.781940   Completed
# 869              130.997386  71.829542   Completed
# 934              124.736359  69.731779    Canceled

# %%
## ADITIONAL ANALYSIS : using indexing
df47i = df47AV[df47AV["BloodPressureSystolic"] == df47AV["BloodPressureSystolic"].max() ]
df47i
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 236      933         884          27  2019-02-14 2019-01-22 19:26:49.163
# 251      888         906          24  2019-03-31 2019-03-17 23:21:17.361
# 424      314          63           7  2019-04-05 2019-03-24 22:31:26.092
# 432      740         892          31  2019-03-14 2019-03-11 15:08:33.963
# 677      929         880          23  2019-02-10 2019-01-22 13:32:14.549
# 869      839         857          12  2019-03-17 2019-02-23 09:05:43.676
# 934      482         866          14  2019-05-04 2019-04-13 07:54:49.580
#
#      VisitDepartmentID     VisitType  BloodPressureSystolic  \
# 236                 12  Telemedicine                  190.0
# 251                 10           New                  190.0
# 424                 11  Telemedicine                  190.0
# 432                  8      Physical                  190.0
# 677                  8     Follow Up                  190.0
# 869                  8     Follow Up                  190.0
# 934                  5           New                  190.0
#
#      BloodPressureDiastolic      Pulse VisitStatus
# 236              143.989174  74.976879   Completed
# 251              137.207999  52.666922   Completed
# 424              121.539859  95.471260   Completed
# 432              145.343479  94.849021   Completed
# 677              144.313400  82.781940   Completed
# 869              130.997386  71.829542   Completed
# 934              124.736359  69.731779    Canceled

# %%
####################################### 48 ###############################################

# %%
# 48. Display the average LOS based on Service and Discharge Disposition
# (Maintain the column Hierarchy)

# %%
df48D = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'Discharges')

# %%
df48D['AdmissionDate'] = pd.to_datetime(df48D['AdmissionDate'])
df48D['DischargeDate'] = pd.to_datetime(df48D['DischargeDate'])

# %%
df48D['AdmissionDate'] = pd.to_datetime(df48D['AdmissionDate']).dt.date
df48D['DischargeDate'] = pd.to_datetime(df48D['DischargeDate']).dt.date

df48D
# Out:
#      AdmissionID  PatientID AdmissionDate DischargeDate DischargeDisposition  \
# 0              1          9    2018-01-01    2018-01-07              Expired
# 1            257         93    2018-01-06    2018-01-18              Expired
# 2            152        101    2018-01-07    2018-01-11              Expired
# 3            361        102    2018-01-07    2018-01-15              Expired
# 4            258        103    2018-01-07    2018-01-15              Expired
# ..           ...        ...           ...           ...                  ...
# 715          715        716    2018-02-21    2018-03-06             Transfer
# 716          698        723    2018-02-22    2018-02-26             Transfer
# 717          704        724    2018-02-22    2018-02-27             Transfer
# 718          716        733    2018-02-22    2018-03-05             Transfer
# 719          710        742    2018-02-22    2018-03-10             Transfer
#
#               Service PrimaryDiagnosis  ExpectedLOS  ExpectedMortality
# 0          Cardiology              AMI     9.646857           0.061540
# 1          Cardiology       Broken Leg     6.816558           0.628827
# 2          Cardiology   Kidney Failure     6.580273           0.573887
# 3          Cardiology             Afib    12.794536           0.222163
# 4          Cardiology       Broken Leg     2.639297           0.055468
# ..                ...              ...          ...                ...
# 715               ICU    Heart Failure    11.362095           0.370695
# 716               ICU    Heart Failure    10.262312           0.812930
# 717  General Medicine        Pneumonia     6.036234           0.094128
# 718               ICU    Heart Failure    13.323413           0.490892
# 719  General Medicine         Diabetes     7.195441           0.286439
#
# [720 rows x 9 columns]

# %%
LOS48 = (df48D['DischargeDate'] - df48D['AdmissionDate'])
LOS48.describe()
# Out:
# count                          720
# mean               9 days 12:50:00
# std      4 days 02:05:06.006769482
# min                3 days 00:00:00
# 25%                6 days 00:00:00
# 50%                9 days 00:00:00
# 75%               13 days 00:00:00
# max               16 days 00:00:00
# dtype: object

# %%
df48D['LengthOS1'] = LOS48
df48D
# Out:
#      AdmissionID  PatientID AdmissionDate DischargeDate DischargeDisposition  \
# 0              1          9    2018-01-01    2018-01-07              Expired
# 1            257         93    2018-01-06    2018-01-18              Expired
# 2            152        101    2018-01-07    2018-01-11              Expired
# 3            361        102    2018-01-07    2018-01-15              Expired
# 4            258        103    2018-01-07    2018-01-15              Expired
# ..           ...        ...           ...           ...                  ...
# 715          715        716    2018-02-21    2018-03-06             Transfer
# 716          698        723    2018-02-22    2018-02-26             Transfer
# 717          704        724    2018-02-22    2018-02-27             Transfer
# 718          716        733    2018-02-22    2018-03-05             Transfer
# 719          710        742    2018-02-22    2018-03-10             Transfer
#
#               Service PrimaryDiagnosis  ExpectedLOS  ExpectedMortality  \
# 0          Cardiology              AMI     9.646857           0.061540
# 1          Cardiology       Broken Leg     6.816558           0.628827
# 2          Cardiology   Kidney Failure     6.580273           0.573887
# 3          Cardiology             Afib    12.794536           0.222163
# 4          Cardiology       Broken Leg     2.639297           0.055468
# ..                ...              ...          ...                ...
# 715               ICU    Heart Failure    11.362095           0.370695
# 716               ICU    Heart Failure    10.262312           0.812930
# 717  General Medicine        Pneumonia     6.036234           0.094128
# 718               ICU    Heart Failure    13.323413           0.490892
# 719  General Medicine         Diabetes     7.195441           0.286439
#
#     LengthOS1
# 0      6 days
# 1     12 days
# 2      4 days
# 3      8 days
# 4      8 days
# ..        ...
# 715   13 days
# 716    4 days
# 717    5 days
# 718   11 days
# 719   16 days
#
# [720 rows x 10 columns]

# %%
df48D1= df48D
df48D1
# Out:
#      AdmissionID  PatientID AdmissionDate DischargeDate DischargeDisposition  \
# 0              1          9    2018-01-01    2018-01-07              Expired
# 1            257         93    2018-01-06    2018-01-18              Expired
# 2            152        101    2018-01-07    2018-01-11              Expired
# 3            361        102    2018-01-07    2018-01-15              Expired
# 4            258        103    2018-01-07    2018-01-15              Expired
# ..           ...        ...           ...           ...                  ...
# 715          715        716    2018-02-21    2018-03-06             Transfer
# 716          698        723    2018-02-22    2018-02-26             Transfer
# 717          704        724    2018-02-22    2018-02-27             Transfer
# 718          716        733    2018-02-22    2018-03-05             Transfer
# 719          710        742    2018-02-22    2018-03-10             Transfer
#
#               Service PrimaryDiagnosis  ExpectedLOS  ExpectedMortality  \
# 0          Cardiology              AMI     9.646857           0.061540
# 1          Cardiology       Broken Leg     6.816558           0.628827
# 2          Cardiology   Kidney Failure     6.580273           0.573887
# 3          Cardiology             Afib    12.794536           0.222163
# 4          Cardiology       Broken Leg     2.639297           0.055468
# ..                ...              ...          ...                ...
# 715               ICU    Heart Failure    11.362095           0.370695
# 716               ICU    Heart Failure    10.262312           0.812930
# 717  General Medicine        Pneumonia     6.036234           0.094128
# 718               ICU    Heart Failure    13.323413           0.490892
# 719  General Medicine         Diabetes     7.195441           0.286439
#
#     LengthOS1
# 0      6 days
# 1     12 days
# 2      4 days
# 3      8 days
# 4      8 days
# ..        ...
# 715   13 days
# 716    4 days
# 717    5 days
# 718   11 days
# 719   16 days
#
# [720 rows x 10 columns]

# %%
DF48 = df48D1.pivot_table(index = ['Service', 'DischargeDisposition'], 
                       values = ['LengthOS1'], aggfunc ='mean')

DF48
# Out:
#                                                       LengthOS1
# Service          DischargeDisposition
# Cardiology       Expired                        8 days 20:48:00
#                  Home                          10 days 04:28:48
#                  Transfer                      11 days 04:48:00
# General Medicine Expired                        8 days 12:00:00
#                  Home                 9 days 18:33:00.786026200
#                  Transfer                      10 days 16:30:00
# Hospitalist      Expired                       10 days 00:00:00
#                  Home                 9 days 00:49:05.454545454
#                  Transfer                       8 days 16:00:00
# ICU              Expired              9 days 06:37:14.482758620
#                  Home                 9 days 03:03:16.363636363
#                  Transfer                       8 days 20:00:00
# Neurology        Expired                       10 days 04:26:40
#                  Home                           9 days 04:40:00
#                  Transfer                      12 days 00:00:00
# Orthopeadics     Expired                       11 days 19:12:00
#                  Home                 8 days 20:18:27.692307692
#                  Transfer                      16 days 00:00:00

# %%
####################################### 49 ###############################################

# %%
# 49. Create a jointplot between expected mortality & expected length of stay

# %%
df49D = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'Discharges')

# %%
# draw jointplot with
# scatter kind
sns.jointplot(x = "ExpectedMortality", y = "ExpectedLOS",
              kind = "hex", data = df49D)

# show the plot
plt.show()

# %%
####################################### 50 ###############################################

# %%
# 50. Which departmentID has maximum number of visits scheduled

# %%
df50AV = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'AmbulatoryVisits' )

# %%
df50vs =df50AV.groupby("VisitDepartmentID")
df50vs

# %%
df50len= df50AV.groupby(["VisitDepartmentID"]).VisitID.agg([len])
df50len
# Out:
#                    len
# VisitDepartmentID
# 1                   51
# 2                   51
# 3                   51
# 4                   51
# 5                   92
# 6                   92
# 7                   93
# 8                   93
# 9                   79
# 10                 100
# 11                 102
# 12                  95

# %%
df50len.loc[11]
# Out:
# len    102
# Name: 11, dtype: int64

# %%
####################################### 51 ###############################################

# %%
# 51. Display patient details where "ReasonForVisit" is either 'Migraine' or 'Pneumonia' and Acuity is 2 or more.

# %%
df51AV = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'EDUnique' )

# %%
df51 = df51AV[(df51AV["PatientID"])  & (df51AV["ReasonForVisit"] == 'Migraine') & (df51AV["Acuity"] >= 2)]
df51
# Out:
#      EDVisitID  PatientID               VisitDate         EDDischargeTime  \
# 22          55          3 2020-01-01 15:01:29.846 2020-01-01 23:11:53.864
# 59         156         65 2020-01-02 17:52:00.856 2020-01-02 23:09:27.926
# 67         192        101 2020-01-03 05:06:23.929 2020-01-03 16:27:48.524
# 69         194        103 2020-01-03 05:44:52.497 2020-01-03 12:58:53.397
# 123        314        223 2020-01-04 20:25:09.037 2020-01-05 11:22:10.005
# 135        350        259 2020-01-05 07:01:24.933 2020-01-05 22:57:29.073
# 137        352        261 2020-01-05 07:46:44.909 2020-01-05 22:19:57.584
# 212        621        367 2020-01-08 15:57:39.576 2020-01-08 22:14:07.316
# 222        655        401 2020-01-09 00:36:02.488 2020-01-09 05:07:45.675
# 224        657        403 2020-01-09 01:18:53.039 2020-01-09 06:06:48.009
# 274        771        517 2020-01-10 12:51:42.131 2020-01-10 14:55:27.935
# 286        807        553 2020-01-11 00:32:48.766 2020-01-11 10:23:21.379
# 288        809        555 2020-01-11 01:33:15.348 2020-01-11 17:36:01.008
# 316        879        625 2020-01-11 20:43:17.680 2020-01-12 15:57:09.980
# 318        881        627 2020-01-11 20:56:32.885 2020-01-12 14:02:08.782
# 349        957        703 2020-01-12 18:09:55.673 2020-01-13 06:13:30.294
# 351        959        705 2020-01-12 18:25:52.770 2020-01-13 08:15:01.918
# 379       1029        775 2020-01-13 15:58:36.876 2020-01-13 20:51:02.585
# 381       1031        777 2020-01-13 16:41:17.795 2020-01-14 06:31:59.602
# 443       1169        915 2020-01-15 05:30:02.889 2020-01-15 18:47:12.044
# 489        188         97 2020-01-03 03:58:31.271 2020-01-03 20:20:18.038
# 491        190         99 2020-01-03 04:24:18.796 2020-01-03 08:54:58.633
# 565        346        255 2020-01-05 05:36:27.207 2020-01-05 14:47:03.618
# 567        348        257 2020-01-05 06:24:33.238 2020-01-06 05:52:57.478
# 634        651        397 2020-01-08 23:30:49.942 2020-01-09 04:07:00.152
# 636        653        399 2020-01-08 23:51:00.404 2020-01-09 10:37:34.710
# 722        803        549 2020-01-10 23:01:02.010 2020-01-11 22:35:13.892
# 724        805        551 2020-01-10 23:38:26.195 2020-01-11 12:11:37.043
# 764        875        621 2020-01-11 19:48:37.663 2020-01-12 13:29:54.909
# 766        877        623 2020-01-11 20:12:22.163 2020-01-12 01:19:00.702
# 809        953        699 2020-01-12 16:58:48.623 2020-01-13 06:57:46.428
# 811        955        701 2020-01-12 17:37:21.061 2020-01-13 15:27:25.197
# 851       1025        771 2020-01-13 14:35:20.917 2020-01-14 08:43:48.112
# 853       1027        773 2020-01-13 15:27:07.001 2020-01-14 13:27:31.778
#
#      Acuity ReasonForVisit EDDisposition
# 22        3       Migraine      admitted
# 59        3       Migraine      admitted
# 67        2       Migraine      Admitted
# 69        3       Migraine      Admitted
# 123       3       Migraine      admitted
# 135       2       Migraine      Admitted
# 137       3       Migraine      Admitted
# 212       3       Migraine      admitted
# 222       2       Migraine      Admitted
# 224       3       Migraine      Admitted
# 274       3       Migraine      admitted
# 286       2       Migraine      Admitted
# 288       3       Migraine      Admitted
# 316       2       Migraine      Admitted
# 318       3       Migraine      Admitted
# 349       2       Migraine      Admitted
# 351       3       Migraine      Admitted
# 379       2       Migraine      Admitted
# 381       3       Migraine      Admitted
# 443       3       Migraine      admitted
# 489       2       Migraine    Discharged
# 491       2       Migraine    Discharged
# 565       2       Migraine    Discharged
# 567       2       Migraine    Discharged
# 634       2       Migraine    Discharged
# 636       2       Migraine    Discharged
# 722       2       Migraine    Discharged
# 724       2       Migraine    Discharged
# 764       2       Migraine    Discharged
# 766       2       Migraine    Discharged
# 809       2       Migraine    Discharged
# 811       2       Migraine    Discharged
# 851       2       Migraine    Discharged
# 853       2       Migraine    Discharged

# %%
####################################### 52 ###############################################

# %%
# 52. Retrieve the row with minimum DBP using sorting technique

# %%
df52AV = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'AmbulatoryVisits' )

# %%
df52sort= df52AV.sort_values(by=['BloodPressureDiastolic'], na_position='last')
df52sort
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 757      163         801          11  2019-02-08 2019-02-07 23:41:12.181
# 456       32          35          32  2019-02-01 2019-01-14 23:07:20.015
# 118      214         852          38  2019-03-31 2019-03-14 18:17:19.979
# 231      909         860           3  2019-04-21 2019-04-12 20:49:25.742
# 545      372         557           3  2019-02-21 2019-02-13 13:05:43.263
# ..       ...         ...         ...         ...                     ...
# 805      666         818          33  2019-02-09 2019-02-01 02:22:14.761
# 807      555          72          35  2019-04-30 2019-04-02 08:38:32.357
# 808      645          90          37  2019-03-16 2019-02-16 17:45:16.908
# 810      773         858          24  2019-03-12 2019-02-25 02:59:43.233
# 813      895         913          31  2019-04-07 2019-03-23 15:12:55.426
#
#      VisitDepartmentID     VisitType  BloodPressureSystolic  \
# 757                  7     Follow Up                  120.0
# 456                  8           New                  121.0
# 118                 10      Physical                  123.0
# 231                  5  Telemedicine                  122.0
# 545                 11     Follow Up                  125.0
# ..                 ...           ...                    ...
# 805                 10      Physical                    NaN
# 807                  7     Follow Up                    NaN
# 808                  1  Telemedicine                    NaN
# 810                  2     Follow Up                    NaN
# 813                  7           New                    NaN
#
#      BloodPressureDiastolic      Pulse VisitStatus
# 757               51.695653  53.310495   Completed
# 456               54.099878  80.480990   Completed
# 118               54.285242  93.909856     No Show
# 231               56.594973  85.179520   Completed
# 545               57.043944  73.071398   Completed
# ..                      ...        ...         ...
# 805                     NaN        NaN   Completed
# 807                     NaN        NaN   Completed
# 808                     NaN        NaN   Completed
# 810                     NaN        NaN   Completed
# 813                     NaN        NaN   Completed
#
# [950 rows x 11 columns]

# %%
df52=df52sort.iloc[0]
df52
# Out:
# VisitID                                          163
# PatientMRN                                       801
# ProviderID                                        11
# DateofVisit                      2019-02-08 00:00:00
# DateScheduled             2019-02-07 23:41:12.181000
# VisitDepartmentID                                  7
# VisitType                                  Follow Up
# BloodPressureSystolic                          120.0
# BloodPressureDiastolic                     51.695653
# Pulse                                      53.310495
# VisitStatus                                Completed
# Name: 757, dtype: object

# %%
####################################### 53 ###############################################bbb

# %%
# 53. Take the ReasonForVisit from user, 
# find the number of patients admitted with that ReasonForVisit

# %%
df53AV = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'EDUnique' )

# %%
df53a = df53AV.groupby("ReasonForVisit")
df53a

# %%
df53 = df53a['ReasonForVisit'].value_counts()
df53
# Out:
# ReasonForVisit       ReasonForVisit
# Accident             Accident                37
# Bleeding             Bleeding                25
# Car Accident         Car Accident            16
# Chest Pain           Chest Pain              91
# Fever                Fever                  172
# Gun Shot             Gun Shot                16
# Intoxication         Intoxication            23
# Laceration           Laceration              22
# Migraine             Migraine               116
# Pneumonia            Pneumonia              171
# Shortness of Breath  Shortness of Breath    120
# Stomach Ache         Stomach Ache           136
# Name: ReasonForVisit, dtype: int64

# %%
####################################### 54 ###############################################

# %%
# 54. Mortality O.E

# %%
from matplotlib.pyplot import figure

# %%
####################################### 55 ###############################################

# %%
# 55. Create a bar chart on service & expected length of stay

# %%
df55D = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'Discharges' )

# %%
#df55a = df55D.plot.bar(x='Service', y='ExpectedLOS', figsize=(15, 10))

# %%
plt.bar(df55D['Service'], height = df55D['ExpectedLOS'], width = 0.9)
# Out:
# <BarContainer object of 720 artists>

# %%
a= df55D.plot.bar(x='Service', y='ExpectedLOS', rot=0, figsize=(15, 10))
a
# Out:
# <AxesSubplot:xlabel='Service'>

# %%
####################################### 56 ###############################################

# %%
# 56. Count of canceled status

# %%
df56AV = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'AmbulatoryVisits' )

# %%
df56 = len(df56NS[df56NS['VisitStatus'] == 'Canceled'])
df56
# Out:
# 60

# %%
####################################### 57 ###############################################

# %%
# 57. Find the age prone to get stroke

# %%
####################################### 58 ###############################################

# %%
# 58. Display total count of patients service wise based on gender

# %%
####################################### 59 ###############################################

# %%
# 59. Create a dataframe by splitting provider name to 
# firstname and lastname with names for the columns

# %%
df59P = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'Providers')

# %%
df59P.head()
# Out:
#    ProviderID    ProviderName ProviderSpecialty     ProviderDateOnStaff
# 0           1       Sally Sue        Pediatrics 1993-01-01 00:00:00.000
# 1           2      Mike Myers        Pediatrics 1993-05-02 00:00:17.695
# 2           3  Jordan Michael        Pediatrics 1993-06-24 21:31:46.687
# 3           4       Ted Texas        Pediatrics 1993-12-23 21:33:52.299
# 4           5        Ala Bama        Pediatrics 1995-01-10 02:53:47.838

# %%
#New data frame with split value columns
df59P[['ProviderFirstName','ProviderLastName']] = df59P["ProviderName"].str.split(" ", expand=True)
df59P
# Out:
#     ProviderID     ProviderName ProviderSpecialty     ProviderDateOnStaff  \
# 0            1        Sally Sue        Pediatrics 1993-01-01 00:00:00.000
# 1            2       Mike Myers        Pediatrics 1993-05-02 00:00:17.695
# 2            3   Jordan Michael        Pediatrics 1993-06-24 21:31:46.687
# 3            4        Ted Texas        Pediatrics 1993-12-23 21:33:52.299
# 4            5         Ala Bama        Pediatrics 1995-01-10 02:53:47.838
# 5            6       Harry Kane        Pediatrics 1995-07-21 03:49:03.310
# 6            7        Barry Bar        Pediatrics 1995-11-21 19:30:38.759
# 7            8        Ted Green        Pediatrics 1996-05-30 06:14:52.539
# 8            9        Ted Black        Pediatrics 1997-02-20 08:01:10.211
# 9           10         Fred Man           Surgery 1998-03-17 01:47:18.794
# 10          11     Kim Kimberly           Surgery 1998-05-10 14:47:29.468
# 11          12         Sarah Ab           Surgery 1998-08-18 05:22:40.762
# 12          13  Abigail Marriot           Surgery 1998-11-08 12:25:45.705
# 13          14          Dave Yu           Surgery 1999-06-26 16:18:57.436
# 14          15  Christian Saint           Surgery 2000-08-27 00:12:40.326
# 15          16     Perry Pardon           Surgery 2001-02-13 11:49:17.862
# 16          17     Kent Kendall        Cardiology 2001-12-22 11:18:32.919
# 17          18       Ryan Kevin        Cardiology 2003-01-14 21:16:34.778
# 18          19     Tyler Conner        Cardiology 2003-07-09 02:41:40.410
# 19          20    Bailey Barret        Cardiology 2003-08-20 16:05:50.179
# 20          21      Megan Bonco        Cardiology 2004-02-17 21:22:30.546
# 21          22    Joesph Walter        Cardiology 2005-02-04 11:40:44.121
# 22          23      Walter King        Cardiology 2006-03-12 22:11:58.070
# 23          24        Luke Long        Cardiology 2006-04-28 00:16:36.762
# 24          25      Justin Time       PrimaryCare 2006-06-21 04:46:36.838
# 25          26      Mike Joseph       PrimaryCare 2006-12-29 16:26:41.085
# 26          27   Bridget Brenda       PrimaryCare 2007-06-30 05:53:46.143
# 27          28      Brenda Bing       PrimaryCare 2007-11-18 22:33:55.792
# 28          29    Chandler Bing       PrimaryCare 2007-12-07 23:50:10.442
# 29          30      Joesph Ross       PrimaryCare 2008-11-08 18:06:32.983
# 30          31     Dwight Scott       PrimaryCare 2009-04-18 19:15:44.587
# 31          32  Michael Halpert       PrimaryCare 2009-09-02 00:14:41.441
# 32          33      Pamela Ding       PrimaryCare 2009-11-12 03:59:49.655
# 33          34       Tony Creed       PrimaryCare 2010-04-28 14:11:26.802
# 34          35  Phyllis Stanley       PrimaryCare 2011-05-05 16:06:03.222
# 35          36        Holly Hue       PrimaryCare 2012-06-24 06:55:22.021
# 36          37        Trent Tye       PrimaryCare 2013-01-12 15:32:21.137
# 37          38    Kimberly Cone       PrimaryCare 2013-05-23 05:17:19.360
# 38          39       Harry West       PrimaryCare 2013-07-14 00:22:03.151
# 39          40     Rosie Renter       PrimaryCare 2013-09-11 12:07:55.584
#
#    ProviderFirstName ProviderLastName
# 0              Sally              Sue
# 1               Mike            Myers
# 2             Jordan          Michael
# 3                Ted            Texas
# 4                Ala             Bama
# 5              Harry             Kane
# 6              Barry              Bar
# 7                Ted            Green
# 8                Ted            Black
# 9               Fred              Man
# 10               Kim         Kimberly
# 11             Sarah               Ab
# 12           Abigail          Marriot
# 13              Dave               Yu
# 14         Christian            Saint
# 15             Perry           Pardon
# 16              Kent          Kendall
# 17              Ryan            Kevin
# 18             Tyler           Conner
# 19            Bailey           Barret
# 20             Megan            Bonco
# 21            Joesph           Walter
# 22            Walter             King
# 23              Luke             Long
# 24            Justin             Time
# 25              Mike           Joseph
# 26           Bridget           Brenda
# 27            Brenda             Bing
# 28          Chandler             Bing
# 29            Joesph             Ross
# 30            Dwight            Scott
# 31           Michael          Halpert
# 32            Pamela             Ding
# 33              Tony            Creed
# 34           Phyllis          Stanley
# 35             Holly              Hue
# 36             Trent              Tye
# 37          Kimberly             Cone
# 38             Harry             West
# 39             Rosie           Renter

# %%
####################################### 60 ###############################################

# %%
# # 60. "Predict the output of the program..
# class Acc: 
# def __init__(self, id): 
# self.id = id
# id = 555 

# acc = Acc(111) 
# print(acc.id)
# "

# %%
class Acc: 
    def __init__(self, id): 
        self.id = id
        id = 555 

acc = Acc(111) 
print(acc.id)
# Out:
# 111

# %%
####################################### 21 ####################################################

# %%
### 21. Which demographic patients are prone to get stroke ###

# %%
df21P = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'Patients')

# %%
df21RR = pd.read_excel("C:\\Users\\Veena\\Desktop\\Python-Hackathon\\HospitalDatabase.xlsx", sheet_name = 'ReAdmissionRegistry')

# %%
df21P1 = df21P["Race"]
df21P1
# Out:
# 0                       White
# 1                       White
# 2                       White
# 3                       White
# 4                       White
#                 ...
# 940    Black/African-American
# 941    Black/African-American
# 942    Black/African-American
# 943    Black/African-American
# 944    Black/African-American
# Name: Race, Length: 945, dtype: object

# %%
df21RR1 = df21RR["PrimaryDiagnosis"]
df21RR1
# Out:
# 0      Kidney Failure
# 1                 Flu
# 2                 Flu
# 3                 Flu
# 4       Heart Failure
#             ...
# 715               AMI
# 716         Pneumonia
# 717         Pneumonia
# 718               Flu
# 719          Diabetes
# Name: PrimaryDiagnosis, Length: 720, dtype: object

# %%
df21ALL = df44P[['PatientID',"Race"]].merge(df44RR[['PatientID',"PrimaryDiagnosis"]], on="PatientID", how="left")
df21ALL
# Out:
#      PatientID                    Race PrimaryDiagnosis
# 0            1                   White   Kidney Failure
# 1            2                   White              Flu
# 2            3                   White              Flu
# 3            4                   White              NaN
# 4            5                   White              Flu
# ..         ...                     ...              ...
# 956        941  Black/African-American              NaN
# 957        942  Black/African-American              NaN
# 958        943  Black/African-American              NaN
# 959        944  Black/African-American              NaN
# 960        945  Black/African-American              NaN
#
# [961 rows x 3 columns]

# %%
df21ALL1 = df21ALL.groupby("PrimaryDiagnosis")

# %%
df21ALL2 = df21ALL1.get_group("Stroke")
df21ALL2
# Out:
#      PatientID                    Race PrimaryDiagnosis
# 9           10                   White           Stroke
# 13          14                   White           Stroke
# 19          19                   White           Stroke
# 35          30                   White           Stroke
# 41          35                   White           Stroke
# ..         ...                     ...              ...
# 615        601  Black/African-American           Stroke
# 616        602  Black/African-American           Stroke
# 625        611  Black/African-American           Stroke
# 656        642  Black/African-American           Stroke
# 686        672                   White           Stroke
#
# [68 rows x 3 columns]

# %%
df21C = df21ALL2["Race"].value_counts()
df21C
# Out:
# Black/African-American    40
# White                     28
# Name: Race, dtype: int64

# %%
df21 = df21C.max()
df21
# Out:
# 40
